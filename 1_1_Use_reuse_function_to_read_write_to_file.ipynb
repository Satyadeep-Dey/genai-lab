# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyadeep-Dey/genai-lab/blob/main/1_1_Use_reuse_function_to_read_write_to_file.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

UTIL_PATH = "/content/drive/MyDrive/Colab Notebooks"
sys.path.insert(0, UTIL_PATH)

# %%
from file_utils_colab import read_text_from_file,write_text_to_file

# %%
# !ls "/content/drive/MyDrive/Colab Notebooks" # lists everything in that folder

# %%
write_text_to_file(
    folder_path="Files/Text",
    file_name="example.txt",
    write_text="Hello, this is just a test on 11-Feb-2026 . We're trying things out ..Isn't it ...!!"
)

# %%
contents = read_text_from_file(
    folder_path="Files/Text",
    file_name="example.txt"
)

print(contents)
